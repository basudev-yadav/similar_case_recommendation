# %% [markdown]
# #TODO
#
# 1. Extract TIDs from OE_LABELS.csv
# 2. Use Indiankanoon API to download the judgements
# 3. Save the html files
# 4. Run BeautifulSoup to create json file
# 5. Create index on elasticsearch
# 6. Run the search code
# 7. Merge this file with new judgements

# %%
#Download the files from Indiankanoon

# %%
import pandas as pd
import numpy as np
import re
import html2text
import requests
from urllib.parse import urljoin
from datetime import datetime
import pandas as pd

# %%
#define the IndianKanoon API class
class IndianKanoon:
  """
    https://github.com/aishik-pyne/kanoon
    Search query	https://api.indiankanoon.org/search/?formInput=<query>&pagenum=<pagenum>
    Document	https://api.indiankanoon.org/doc/<docid>/
    Document fragments	https://api.indiankanoon.org/docfragment/<docid>/?formInput=<query>
    Document Metainfo	https://api.indiankanoon.org/docmeta/<docid>/
  """

  def __init__(self):
    self.base_url = "https://api.indiankanoon.org/"
    #self.auth_token is a newly generated token from the IndiaKanoon API website(you have to generate it manually)
    self.auth_token = "d3e1691b8001c42d17aa0269d11e46207e9cc5d6"
    
    self.headers = {
        'authorization': "Token {}".format(self.auth_token),
        'cache-control': "no-cache",
    }
    self.api_session = requests.Session()
    self.api_session.headers = self.headers

  def search(self, formInput, pagenum=0,
             fromdate=None, todate=None,
             title=None, author=None,
             cite=None, bench=None, maxpages=50):
    #  Creating parameters
    params = {
        'formInput': formInput,
        'pagenum': pagenum,
        'maxpages': maxpages
    }
    if fromdate:
      assert isinstance(fromdate, datetime) 
      params['fromdate'] = fromdate.strftime('%d-%m-&Y')

    if todate:
      assert isinstance(todate, datetime) 
      params['todate'] = todate.strftime('%d-%m-&Y')

    # Making the request
    response = self.api_session.post(
        urljoin(self.base_url, 'search/'), params=params)
    response.raise_for_status()
    return response.json()

  def doc(self, docid):
    response = self.api_session.post(
        urljoin(self.base_url, 'doc/{}/'.format(docid)))
    response.raise_for_status()
    return response.json()

  def docfragment(self, docid, formInput):
    params = {
        'formInput': formInput,
    }
    response = self.api_session.post(
        urljoin(self.base_url, 'docfragment/{}/'.format(docid)), params=params)
    response.raise_for_status()
    return response.json()

  def docmeta(self, docid):
    response = self.api_session.post(
        urljoin(self.base_url, 'docmeta/{}/'.format(docid)))
    response.raise_for_status()
    return response.json()

# %%
#initialize object
ik = IndianKanoon()

# %%
#returns document id from link
def get_id(link):
    regex = re.compile(r'[0-9]+')
    result = regex.search(link)
    
    if(result):
        return result.group()
    else:
        return ""

# %%
oe_old = pd.read_csv("OE_LABELS.csv")

# %%
#get tids from file
res = []
for i in range(oe_old.shape[0]):
    res.append(int(oe_old.iloc[i,0]))

# %%
res
# Out:
# [928322,
#  699319,
#  1988649,
#  1362442,
#  357132,
#  1722050,
#  985842,
#  617044,
#  1885635,
#  104810373,
#  4354,
#  174974,
#  1341112,
#  64332,
#  334293,
#  137050,
#  30319311,
#  832781,
#  1567371,
#  76636976,
#  1168060,
#  634266,
#  1664373,
#  42294818,
#  1350547,
#  199977,
#  48216667,
#  611025,
#  762747,
#  268937,
#  104312764,
#  353751,
#  584252,
#  1327080,
#  1426304,
#  1951505,
#  91635,
#  8919089,
#  844819,
#  634059,
#  1013766,
#  1187885,
#  68469,
#  1771435,
#  557368,
#  743158,
#  1928398,
#  309271,
#  1295746,
#  938898,
#  1134697,
#  1505859,
#  310087,
#  91986422,
#  380655,
#  1830927,
#  33136745,
#  912526,
#  292286,
#  1716282,
#  429924,
#  176039345,
#  508915,
#  810279,
#  88087196,
#  309307,
#  69624144,
#  170697,
#  1154981,
#  1474119,
#  42355707,
#  146940961,
#  1278222,
#  62991042,
#  223504,
#  31239895,
#  582634,
#  2671204,
#  1030976,
#  1905157,
#  672966,
#  528391,
#  94788795,
#  292442,
#  52129591,
#  1187886,
#  1022584,
#  486081,
#  860600,
#  444303,
#  1341716,
#  1877462,
#  1500505,
#  1353689,
#  994554,
#  6544121,
#  6137338,
#  1103984,
#  465681,
#  867423,
#  1991497,
#  1960330,
#  109874394,
#  71315,
#  280485,
#  1129833,
#  639803,
#  206804,
#  36937,
#  382721,
#  379222,
#  875590,
#  1246653,
#  590022,
#  837614,
#  176508424,
#  39169380,
#  37963,
#  1641452,
#  108020655,
#  1700195,
#  1697217,
#  1831036,
#  794955,
#  33194727,
#  962370,
#  1271015,
#  1615016,
#  1053542,
#  20356733,
#  1304475,
#  849254,
#  241970,
#  468834,
#  1023674,
#  1482259,
#  653417,
#  329158,
#  199908142,
#  1484358,
#  403501,
#  1147125,
#  17789938,
#  491934,
#  1763592,
#  296025,
#  54995969,
#  458739,
#  1752565,
#  96002,
#  128161,
#  1341895,
#  165621647,
#  980877,
#  1725672,
#  1130742,
#  111777378,
#  279427,
#  1754074,
#  784749,
#  732612,
#  1414629,
#  857323,
#  47808634,
#  1867924,
#  1333219,
#  1186368,
#  102886851,
#  1610804,
#  736105,
#  1566,
#  605322,
#  1902038,
#  74910860,
#  51689837,
#  6547,
#  1844910,
#  1024124,
#  79561,
#  119316583,
#  1890994,
#  982330,
#  175238601,
#  793618,
#  181459283,
#  1281050,
#  1149874,
#  625240,
#  871220,
#  866760,
#  1240131,
#  162432291,
#  1131957,
#  946842,
#  1163546,
#  864375,
#  1299452,
#  306336,
#  1732220,
#  5114588,
#  26718353,
#  1742704,
#  169522737,
#  735457,
#  138217214,
#  1462242,
#  1599972,
#  391843,
#  1672214,
#  137734242,
#  1882267,
#  290962,
#  1920837,
#  292146,
#  176122260,
#  189337794,
#  1147963,
#  565540,
#  275246,
#  1695101,
#  893844,
#  386457,
#  1576587,
#  1442144,
#  476474,
#  941137,
#  896874,
#  39679,
#  1329151,
#  2044127,
#  524871,
#  1960340,
#  1965204,
#  168489488,
#  1738256,
#  988645,
#  315836,
#  1465670,
#  1276331,
#  183984262,
#  435765,
#  166007515,
#  1514512,
#  96932,
#  112850760,
#  1300072,
#  1629830,
#  1907642,
#  685234,
#  1194654,
#  1475926,
#  1668065,
#  70463837,
#  1869992,
#  104377,
#  70487596,
#  710165,
#  317172,
#  1916388,
#  1326499,
#  769115,
#  833158,
#  467194,
#  850428,
#  963790,
#  80997184,
#  1097981,
#  1856009,
#  40533940,
#  1247926,
#  281850,
#  762055,
#  56087922,
#  652828,
#  894494,
#  1831078,
#  1487019,
#  50089303,
#  47391891,
#  681866,
#  1543503,
#  189907,
#  1159790,
#  1355660,
#  1586918,
#  1330629,
#  1378876,
#  1425094,
#  487303,
#  288525,
#  248715,
#  350628,
#  1334665,
#  64231867,
#  1550190,
#  1104087,
#  162420,
#  1354608,
#  1292071,
#  1056935,
#  442517,
#  414792,
#  1813801,
#  1214980,
#  290385,
#  525017,
#  1156538,
#  65293457,
#  627069,
#  347224,
#  691481,
#  103434922,
#  1073828,
#  1911637,
#  453977,
#  1213194,
#  188348,
#  112896520,
#  1212077,
#  1738333,
#  529229,
#  574884,
#  1923487,
#  323576,
#  63283859,
#  85467018,
#  455122,
#  1382698,
#  1954356,
#  194456776,
#  1999324,
#  603848,
#  850821,
#  1411268,
#  85089691,
#  41554823,
#  977497,
#  1006468,
#  1425907,
#  1597179,
#  494408,
#  1604568,
#  63489929,
#  181033,
#  1507797,
#  1741949,
#  1766312,
#  58263027,
#  509065,
#  338008,
#  1986616,
#  1022090,
#  769926,
#  81086651,
#  120358,
#  1202878,
#  651705,
#  246887,
#  693281,
#  105936170,
#  1092394,
#  1199558,
#  65151197,
#  1767393,
#  446174,
#  1869228,
#  1806604,
#  133640019,
#  94514,
#  1611775,
#  1660833,
#  687034,
#  1274327,
#  950361,
#  1877956,
#  890637,
#  1006709,
#  1401520,
#  1656601,
#  619152,
#  1292463,
#  1589218,
#  99670896,
#  3849421,
#  96706,
#  743328,
#  1213021,
#  1007946,
#  407511,
#  102852,
#  314044,
#  81824666,
#  757639,
#  1815080,
#  1120137,
#  1121229,
#  629330,
#  424874,
#  67255,
#  1104701,
#  1086058,
#  816271,
#  1261492,
#  317554,
#  307021,
#  151308629,
#  214713,
#  130353321,
#  1038563,
#  29023706,
#  1643349,
#  410114,
#  165099707,
#  187706,
#  39217891,
#  1326478,
#  1206795,
#  261992,
#  511784,
#  1405951,
#  165968354,
#  160205361,
#  184660633,
#  761967,
#  471272,
#  657557,
#  179814250,
#  873775,
#  1596320,
#  112937069,
#  89164,
#  1297488,
#  1564015,
#  107853771,
#  1278868,
#  540642,
#  911084,
#  1440160,
#  183600564,
#  1033812,
#  759618,
#  1861080,
#  1110013,
#  150473,
#  309541,
#  1313207,
#  1307266,
#  75646,
#  1151918,
#  1033637,
#  183717026,
#  996328,
#  1989264,
#  175829,
#  693891,
#  74028,
#  1723469,
#  1900118,
#  188429772,
#  1940266,
#  952975,
#  109700315,
#  27773000,
#  231341,
#  885778,
#  80498353,
#  425153,
#  135809,
#  1685319,
#  1509628,
#  1822024,
#  501542,
#  152460,
#  1098305,
#  1999671,
#  1719469,
#  678038,
#  1483262,
#  1290723,
#  81716407,
#  188357431,
#  1750914,
#  181654439,
#  82620,
#  620904,
#  579822,
#  1382657,
#  1453719,
#  1134429,
#  155272316,
#  1682715,
#  1718159,
#  1132299,
#  73583860,
#  820931,
#  647343,
#  1616148,
#  1703545,
#  850597,
#  1659850,
#  899744,
#  1536230,
#  1988625,
#  1947054,
#  1611623,
#  1224686,
#  344644,
#  1939993,
#  1662395,
#  55517912,
#  108509106,
#  67143323,
#  279466,
#  1014138,
#  350976,
#  28356393,
#  899181,
#  1979794,
#  968805,
#  374340,
#  161939,
#  73767384,
#  1798615,
#  68799740,
#  1195618,
#  1439704,
#  1519371,
#  138826371,
#  1986966,
#  821579,
#  1416283,
#  1052178,
#  37934,
#  1850663,
#  1115541,
#  1578200,
#  1521407,
#  612964,
#  1120277,
#  936398,
#  1706612,
#  10239019,
#  913118,
#  1963322,
#  1319506,
#  91088,
#  115718142,
#  973363,
#  1655935,
#  585040,
#  511635,
#  630125,
#  1901943,
#  162878090,
#  1695291,
#  1847057,
#  891864,
#  794450,
#  756739,
#  681713,
#  135953,
#  139670361,
#  1216757,
#  861349,
#  1438183,
#  16810704,
#  5192,
#  1166220,
#  1677837,
#  492853,
#  1338327,
#  135285745,
#  456839,
#  27152913,
#  1165503,
#  1741822,
#  1555192,
#  89564,
#  172383107,
#  415294,
#  513801,
#  446828,
#  74061245,
#  1596866,
#  53080,
#  100123,
#  85777093,
#  1470887,
#  151609698,
#  1300646,
#  499867,
#  805786,
#  1099140,
#  1799441,
#  1381953,
#  1287305,
#  1866073,
#  1233850,
#  1771880,
#  23954109,
#  1567797,
#  507033,
#  996348,
#  146267,
#  1152518,
#  919121,
#  1120373,
#  1445734,
#  600280,
#  1233360,
#  819445,
#  104313664,
#  37987,
#  1802196,
#  1961394,
#  130087,
#  1919561,
#  623061,
#  1594031,
#  1874558,
#  1407895,
#  936707,
#  213382,
#  1447296,
#  14898186,
#  37494799,
#  192914986,
#  118501220,
#  1401567,
#  118046405,
#  143917974,
#  1404351,
#  1714313,
#  952082,
#  212274,
#  512761,
#  877389,
#  256224,
#  1097490,
#  633111,
#  54865315,
#  1890740,
#  514933,
#  1956673,
#  195994,
#  350457,
#  363089,
#  907493,
#  904832,
#  686582,
#  7926018,
#  585219,
#  3111930,
#  1648254,
#  166780307,
#  124137051,
#  707249,
#  183120061,
#  1568935,
#  483734,
#  620033,
#  843614,
#  1521460,
#  211970,
#  477104,
#  37721629,
#  14377547,
#  1903089,
#  1747577,
#  681372,
#  997135,
#  511928,
#  477313,
#  1537954,
#  399708,
#  919241,
#  23402471,
#  154833956,
#  69052901,
#  1019490,
#  452434,
#  1969682,
#  1239673,
#  1887773,
#  588099,
#  187501619,
#  161147300,
#  483899,
#  883586,
#  1602162,
#  354829,
#  1543623,
#  1836621,
#  899938,
#  1877641,
#  396205,
#  1296255,
#  222788,
#  794815,
#  1231997,
#  614998,
#  1899039,
#  280498,
#  7003391,
#  332955,
#  150814946,
#  838466,
#  1318646,
#  101008236,
#  693363,
#  82895350,
#  939624,
#  1938230,
#  198827109,
#  179794777,
#  31621011,
#  557776,
#  1136885,
#  1237504,
#  795465,
#  86904342,
#  1515299,
#  18546,
#  753224,
#  264657,
#  138184,
#  659090,
#  774102,
#  1102062,
#  1186410,
#  1640744,
#  42299665,
#  1732339,
#  1907957,
#  1180101,
#  1881313,
#  1418391,
#  712132,
#  49480,
#  1012649,
#  83741552,
#  995861,
#  856194,
#  1011356,
#  1375132,
#  1633179,
#  102653512,
#  877414,
#  1486034,
#  861510,
#  164002734,
#  793348,
#  1486949,
#  83406,
#  1363234,
#  293197,
#  762574,
#  371933,
#  1403823,
#  1377335,
#  992249,
#  220229,
#  713825,
#  1668551,
#  1132362,
#  816411,
#  263884,
#  190196010,
#  227988,
#  36875,
#  44641638,
#  1737054,
#  1291316,
#  3173546,
#  1136663,
#  665756,
#  180850491,
#  437533,
#  1048632,
#  139299795,
#  88397,
#  86762634,
#  243002,
#  450219,
#  1763149,
#  79280249,
#  1677896,
#  57798471,
#  1105134,
#  1891895,
#  5398766,
#  306833,
#  730804,
#  342903,
#  188958994,
#  514077,
#  1878548,
#  1876565,
#  1206754,
#  51545606,
#  1735815,
#  383397,
#  60799,
#  315432,
#  1155640,
#  1732840,
#  673012,
#  163696803,
#  1328814,
#  113963352,
#  1602137,
#  1765871,
#  952963,
#  474885,
#  249589,
#  858066,
#  127517806,
#  1338837,
#  204742,
#  1548289,
#  1965879,
#  1062099,
#  116548206,
#  165776436,
#  712415,
#  733192,
#  134913,
#  145401736,
#  1938862,
#  880032,
#  104935066,
#  1397964,
#  1035346,
#  444914,
#  280042,
#  44410582,
#  1335881,
#  1883538,
#  191907197,
#  119540048,
#  1857950,
#  1403309,
#  161614515,
#  341560,
#  368264,
#  1514111,
#  1584936,
#  1106747,
#  925897,
#  110813550,
#  1981010,
#  421030,
#  258508,
#  584977,
#  617728,
#  1209528,
#  1734007,
#  103561,
#  1528386,
#  896743,
#  98622476,
#  614536,
#  143202244,
#  155579055,
#  869781,
#  858492,
#  224777,
#  955097,
#  1001948,
#  155329262,
#  57555980,
#  784265,
#  126699,
#  130470,
#  1592558,
#  910213,
#  179477870,
#  191721813,
#  21369704,
#  591481,
#  1415114,
#  331232,
#  422732,
#  38764718,
#  103057287,
#  271216,
#  257876,
#  115701246,
#  148082701,
#  1180206,
#  66104323,
#  1805387,
#  789627,
#  43335747,
#  1669803,
#  634160,
#  1180216,
#  1326449,
#  1508554,
#  328927,
#  70037708,
#  1817694,
#  1365277,
#  800341,
#  1114158,
#  1181080,
#  138192511,
#  99622088,
#  40753175,
#  594383,
#  1231223,
#  178445,
#  1771122,
#  183868316,
#  1627481,
#  353578,
#  1035719,
#  1220952,
#  377266,
#  1671648,
#  1389940,
#  865758,
#  122362,
#  703764,
#  338115,
#  98342524,
#  529384,
#  668225,
#  19267666,
#  167333165,
#  67892682,
#  1766147,
#  1242789,
#  1643138,
#  93127,
#  1572876,
#  1674695,
#  137238378,
#  943008,
#  623494,
#  1300681,
#  615459,
#  1630167,
#  175175391,
#  1727525,
#  1425329,
#  1663733,
#  1593570,
#  1926500,
#  576454,
#  565788,
#  1959866,
#  1967742,
#  12050516,
#  123737198,
#  1307808,
#  1747781,
#  330608]

# %%
res[80:]
# Out:
# [672966,
#  528391,
#  94788795,
#  292442,
#  52129591,
#  1187886,
#  1022584,
#  486081,
#  860600,
#  444303,
#  1341716,
#  1877462,
#  1500505,
#  1353689,
#  994554,
#  6544121,
#  6137338,
#  1103984,
#  465681,
#  867423,
#  1991497,
#  1960330,
#  109874394,
#  71315,
#  280485,
#  1129833,
#  639803,
#  206804,
#  36937,
#  382721,
#  379222,
#  875590,
#  1246653,
#  590022,
#  837614,
#  176508424,
#  39169380,
#  37963,
#  1641452,
#  108020655,
#  1700195,
#  1697217,
#  1831036,
#  794955,
#  33194727,
#  962370,
#  1271015,
#  1615016,
#  1053542,
#  20356733,
#  1304475,
#  849254,
#  241970,
#  468834,
#  1023674,
#  1482259,
#  653417,
#  329158,
#  199908142,
#  1484358,
#  403501,
#  1147125,
#  17789938,
#  491934,
#  1763592,
#  296025,
#  54995969,
#  458739,
#  1752565,
#  96002,
#  128161,
#  1341895,
#  165621647,
#  980877,
#  1725672,
#  1130742,
#  111777378,
#  279427,
#  1754074,
#  784749,
#  732612,
#  1414629,
#  857323,
#  47808634,
#  1867924,
#  1333219,
#  1186368,
#  102886851,
#  1610804,
#  736105,
#  1566,
#  605322,
#  1902038,
#  74910860,
#  51689837,
#  6547,
#  1844910,
#  1024124,
#  79561,
#  119316583,
#  1890994,
#  982330,
#  175238601,
#  793618,
#  181459283,
#  1281050,
#  1149874,
#  625240,
#  871220,
#  866760,
#  1240131,
#  162432291,
#  1131957,
#  946842,
#  1163546,
#  864375,
#  1299452,
#  306336,
#  1732220,
#  5114588,
#  26718353,
#  1742704,
#  169522737,
#  735457,
#  138217214,
#  1462242,
#  1599972,
#  391843,
#  1672214,
#  137734242,
#  1882267,
#  290962,
#  1920837,
#  292146,
#  176122260,
#  189337794,
#  1147963,
#  565540,
#  275246,
#  1695101,
#  893844,
#  386457,
#  1576587,
#  1442144,
#  476474,
#  941137,
#  896874,
#  39679,
#  1329151,
#  2044127,
#  524871,
#  1960340,
#  1965204,
#  168489488,
#  1738256,
#  988645,
#  315836,
#  1465670,
#  1276331,
#  183984262,
#  435765,
#  166007515,
#  1514512,
#  96932,
#  112850760,
#  1300072,
#  1629830,
#  1907642,
#  685234,
#  1194654,
#  1475926,
#  1668065,
#  70463837,
#  1869992,
#  104377,
#  70487596,
#  710165,
#  317172,
#  1916388,
#  1326499,
#  769115,
#  833158,
#  467194,
#  850428,
#  963790,
#  80997184,
#  1097981,
#  1856009,
#  40533940,
#  1247926,
#  281850,
#  762055,
#  56087922,
#  652828,
#  894494,
#  1831078,
#  1487019,
#  50089303,
#  47391891,
#  681866,
#  1543503,
#  189907,
#  1159790,
#  1355660,
#  1586918,
#  1330629,
#  1378876,
#  1425094,
#  487303,
#  288525,
#  248715,
#  350628,
#  1334665,
#  64231867,
#  1550190,
#  1104087,
#  162420,
#  1354608,
#  1292071,
#  1056935,
#  442517,
#  414792,
#  1813801,
#  1214980,
#  290385,
#  525017,
#  1156538,
#  65293457,
#  627069,
#  347224,
#  691481,
#  103434922,
#  1073828,
#  1911637,
#  453977,
#  1213194,
#  188348,
#  112896520,
#  1212077,
#  1738333,
#  529229,
#  574884,
#  1923487,
#  323576,
#  63283859,
#  85467018,
#  455122,
#  1382698,
#  1954356,
#  194456776,
#  1999324,
#  603848,
#  850821,
#  1411268,
#  85089691,
#  41554823,
#  977497,
#  1006468,
#  1425907,
#  1597179,
#  494408,
#  1604568,
#  63489929,
#  181033,
#  1507797,
#  1741949,
#  1766312,
#  58263027,
#  509065,
#  338008,
#  1986616,
#  1022090,
#  769926,
#  81086651,
#  120358,
#  1202878,
#  651705,
#  246887,
#  693281,
#  105936170,
#  1092394,
#  1199558,
#  65151197,
#  1767393,
#  446174,
#  1869228,
#  1806604,
#  133640019,
#  94514,
#  1611775,
#  1660833,
#  687034,
#  1274327,
#  950361,
#  1877956,
#  890637,
#  1006709,
#  1401520,
#  1656601,
#  619152,
#  1292463,
#  1589218,
#  99670896,
#  3849421,
#  96706,
#  743328,
#  1213021,
#  1007946,
#  407511,
#  102852,
#  314044,
#  81824666,
#  757639,
#  1815080,
#  1120137,
#  1121229,
#  629330,
#  424874,
#  67255,
#  1104701,
#  1086058,
#  816271,
#  1261492,
#  317554,
#  307021,
#  151308629,
#  214713,
#  130353321,
#  1038563,
#  29023706,
#  1643349,
#  410114,
#  165099707,
#  187706,
#  39217891,
#  1326478,
#  1206795,
#  261992,
#  511784,
#  1405951,
#  165968354,
#  160205361,
#  184660633,
#  761967,
#  471272,
#  657557,
#  179814250,
#  873775,
#  1596320,
#  112937069,
#  89164,
#  1297488,
#  1564015,
#  107853771,
#  1278868,
#  540642,
#  911084,
#  1440160,
#  183600564,
#  1033812,
#  759618,
#  1861080,
#  1110013,
#  150473,
#  309541,
#  1313207,
#  1307266,
#  75646,
#  1151918,
#  1033637,
#  183717026,
#  996328,
#  1989264,
#  175829,
#  693891,
#  74028,
#  1723469,
#  1900118,
#  188429772,
#  1940266,
#  952975,
#  109700315,
#  27773000,
#  231341,
#  885778,
#  80498353,
#  425153,
#  135809,
#  1685319,
#  1509628,
#  1822024,
#  501542,
#  152460,
#  1098305,
#  1999671,
#  1719469,
#  678038,
#  1483262,
#  1290723,
#  81716407,
#  188357431,
#  1750914,
#  181654439,
#  82620,
#  620904,
#  579822,
#  1382657,
#  1453719,
#  1134429,
#  155272316,
#  1682715,
#  1718159,
#  1132299,
#  73583860,
#  820931,
#  647343,
#  1616148,
#  1703545,
#  850597,
#  1659850,
#  899744,
#  1536230,
#  1988625,
#  1947054,
#  1611623,
#  1224686,
#  344644,
#  1939993,
#  1662395,
#  55517912,
#  108509106,
#  67143323,
#  279466,
#  1014138,
#  350976,
#  28356393,
#  899181,
#  1979794,
#  968805,
#  374340,
#  161939,
#  73767384,
#  1798615,
#  68799740,
#  1195618,
#  1439704,
#  1519371,
#  138826371,
#  1986966,
#  821579,
#  1416283,
#  1052178,
#  37934,
#  1850663,
#  1115541,
#  1578200,
#  1521407,
#  612964,
#  1120277,
#  936398,
#  1706612,
#  10239019,
#  913118,
#  1963322,
#  1319506,
#  91088,
#  115718142,
#  973363,
#  1655935,
#  585040,
#  511635,
#  630125,
#  1901943,
#  162878090,
#  1695291,
#  1847057,
#  891864,
#  794450,
#  756739,
#  681713,
#  135953,
#  139670361,
#  1216757,
#  861349,
#  1438183,
#  16810704,
#  5192,
#  1166220,
#  1677837,
#  492853,
#  1338327,
#  135285745,
#  456839,
#  27152913,
#  1165503,
#  1741822,
#  1555192,
#  89564,
#  172383107,
#  415294,
#  513801,
#  446828,
#  74061245,
#  1596866,
#  53080,
#  100123,
#  85777093,
#  1470887,
#  151609698,
#  1300646,
#  499867,
#  805786,
#  1099140,
#  1799441,
#  1381953,
#  1287305,
#  1866073,
#  1233850,
#  1771880,
#  23954109,
#  1567797,
#  507033,
#  996348,
#  146267,
#  1152518,
#  919121,
#  1120373,
#  1445734,
#  600280,
#  1233360,
#  819445,
#  104313664,
#  37987,
#  1802196,
#  1961394,
#  130087,
#  1919561,
#  623061,
#  1594031,
#  1874558,
#  1407895,
#  936707,
#  213382,
#  1447296,
#  14898186,
#  37494799,
#  192914986,
#  118501220,
#  1401567,
#  118046405,
#  143917974,
#  1404351,
#  1714313,
#  952082,
#  212274,
#  512761,
#  877389,
#  256224,
#  1097490,
#  633111,
#  54865315,
#  1890740,
#  514933,
#  1956673,
#  195994,
#  350457,
#  363089,
#  907493,
#  904832,
#  686582,
#  7926018,
#  585219,
#  3111930,
#  1648254,
#  166780307,
#  124137051,
#  707249,
#  183120061,
#  1568935,
#  483734,
#  620033,
#  843614,
#  1521460,
#  211970,
#  477104,
#  37721629,
#  14377547,
#  1903089,
#  1747577,
#  681372,
#  997135,
#  511928,
#  477313,
#  1537954,
#  399708,
#  919241,
#  23402471,
#  154833956,
#  69052901,
#  1019490,
#  452434,
#  1969682,
#  1239673,
#  1887773,
#  588099,
#  187501619,
#  161147300,
#  483899,
#  883586,
#  1602162,
#  354829,
#  1543623,
#  1836621,
#  899938,
#  1877641,
#  396205,
#  1296255,
#  222788,
#  794815,
#  1231997,
#  614998,
#  1899039,
#  280498,
#  7003391,
#  332955,
#  150814946,
#  838466,
#  1318646,
#  101008236,
#  693363,
#  82895350,
#  939624,
#  1938230,
#  198827109,
#  179794777,
#  31621011,
#  557776,
#  1136885,
#  1237504,
#  795465,
#  86904342,
#  1515299,
#  18546,
#  753224,
#  264657,
#  138184,
#  659090,
#  774102,
#  1102062,
#  1186410,
#  1640744,
#  42299665,
#  1732339,
#  1907957,
#  1180101,
#  1881313,
#  1418391,
#  712132,
#  49480,
#  1012649,
#  83741552,
#  995861,
#  856194,
#  1011356,
#  1375132,
#  1633179,
#  102653512,
#  877414,
#  1486034,
#  861510,
#  164002734,
#  793348,
#  1486949,
#  83406,
#  1363234,
#  293197,
#  762574,
#  371933,
#  1403823,
#  1377335,
#  992249,
#  220229,
#  713825,
#  1668551,
#  1132362,
#  816411,
#  263884,
#  190196010,
#  227988,
#  36875,
#  44641638,
#  1737054,
#  1291316,
#  3173546,
#  1136663,
#  665756,
#  180850491,
#  437533,
#  1048632,
#  139299795,
#  88397,
#  86762634,
#  243002,
#  450219,
#  1763149,
#  79280249,
#  1677896,
#  57798471,
#  1105134,
#  1891895,
#  5398766,
#  306833,
#  730804,
#  342903,
#  188958994,
#  514077,
#  1878548,
#  1876565,
#  1206754,
#  51545606,
#  1735815,
#  383397,
#  60799,
#  315432,
#  1155640,
#  1732840,
#  673012,
#  163696803,
#  1328814,
#  113963352,
#  1602137,
#  1765871,
#  952963,
#  474885,
#  249589,
#  858066,
#  127517806,
#  1338837,
#  204742,
#  1548289,
#  1965879,
#  1062099,
#  116548206,
#  165776436,
#  712415,
#  733192,
#  134913,
#  145401736,
#  1938862,
#  880032,
#  104935066,
#  1397964,
#  1035346,
#  444914,
#  280042,
#  44410582,
#  1335881,
#  1883538,
#  191907197,
#  119540048,
#  1857950,
#  1403309,
#  161614515,
#  341560,
#  368264,
#  1514111,
#  1584936,
#  1106747,
#  925897,
#  110813550,
#  1981010,
#  421030,
#  258508,
#  584977,
#  617728,
#  1209528,
#  1734007,
#  103561,
#  1528386,
#  896743,
#  98622476,
#  614536,
#  143202244,
#  155579055,
#  869781,
#  858492,
#  224777,
#  955097,
#  1001948,
#  155329262,
#  57555980,
#  784265,
#  126699,
#  130470,
#  1592558,
#  910213,
#  179477870,
#  191721813,
#  21369704,
#  591481,
#  1415114,
#  331232,
#  422732,
#  38764718,
#  103057287,
#  271216,
#  257876,
#  115701246,
#  148082701,
#  1180206,
#  66104323,
#  1805387,
#  789627,
#  43335747,
#  1669803,
#  634160,
#  1180216,
#  1326449,
#  1508554,
#  328927,
#  70037708,
#  1817694,
#  1365277,
#  800341,
#  1114158,
#  1181080,
#  138192511,
#  99622088,
#  40753175,
#  594383,
#  1231223,
#  178445,
#  1771122,
#  183868316,
#  1627481,
#  353578,
#  1035719,
#  1220952,
#  377266,
#  1671648,
#  1389940,
#  865758,
#  122362,
#  703764,
#  338115,
#  98342524,
#  529384,
#  668225,
#  19267666,
#  167333165,
#  67892682,
#  1766147,
#  1242789,
#  1643138,
#  93127,
#  1572876,
#  1674695,
#  137238378,
#  943008,
#  623494,
#  1300681,
#  615459,
#  1630167,
#  175175391,
#  1727525,
#  1425329,
#  1663733,
#  1593570,
#  1926500,
#  576454,
#  565788,
#  1959866,
#  1967742,
#  12050516,
#  123737198,
#  1307808,
#  1747781,
#  330608]

# %%
docs = []

count = 0
for i in res[80:]:
    docs.append(ik.doc(docid=str(i)))
    print("FILE NUMBER: ",(count+1))
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-37-4a0f5f9c732d> in <module>
#       3 count = 0
#       4 for i in res[80:]:
# ----> 5     docs.append(ik.doc(docid=str(i)))
#       6     print("FILE NUMBER: ",(count+1))
#       7     count = count + 1
#
# <ipython-input-35-7a32df513cf9> in doc(self, docid)
#      48     response = self.api_session.post(
#      49         urljoin(self.base_url, 'doc/{}/'.format(docid)))
# ---> 50     response.raise_for_status()
#      51     return response.json()
#      52
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.indiankanoon.org/doc/672966/

# %%
X = pd.DataFrame.from_dict(docs)

# %%
X
# Out:
#          tid covertids publishdate firstname secondname    lastname  \
# 0     928322        []  1993-05-05         k       None   ramaswamy
# 1     699319        []  1989-11-09         k       None      saikia
# 2    1988649        []  2005-08-16         a       None     pasayat
# 3    1362442        []  1993-09-17         k       None   ramaswamy
# 4     357132        []  1971-02-19         i       None         dua
# ..       ...       ...         ...       ...        ...         ...
# 75  31239895        []  2018-05-01      None       None        None
# 76    582634        []  2007-06-07         a       None  khanwilkar
# 77   2671204        []  2000-05-12         s       None       ahmad
# 78   1030976        []  2011-11-04         r       None    shakdher
# 79   1905157        []  1978-12-13      None       None        None
#
#                                                 title  \
# 0   Ajay Agarwal vs Union Of India And Ors on 5 Ma...
# 1   S.M.D. Kiran Pasha vs Government Of Andhra Pra...
# 2   Smt. Rani Kusum vs Smt. Kanchan Devi And Ors o...
# 3   Desh Bandhu Gupta vs N.L.Anand & Rajinder Sing...
# 4   Baburao Bajirao Patil vs State Of Maharashtra ...
# ..                                                ...
# 75  Prakash Kumar Jha vs State Of Uttarakhand on 1...
# 76  Urmi Juvekar Chiang vs Global Broadcast News L...
# 77  P. Sarathy vs State Bank Of India on 12 May, 2000
# 78  Commissioner Of Income Tax vs M/S Asahi India ...
# 79  Biswanath Prasad Radhey Shyam vs Hindustan Met...
#
#                                              filename  \
# 0   judis.nic.in/1993-05-05/AJAY AGARWAL Vs. UNION...
# 1   judis.nic.in/1989-11-09/S.M.D. KIRAN PASHA Vs....
# 2   judis.nic.in/2005-08-16/Smt. Rani Kusum Vs. Sm...
# 3   judis.nic.in/1993-09-17/DESH BANDHU GUPTA Vs. ...
# 4   www.manupatra.co.in/NXT/gateway.dll/sc/1950-19...
# ..                                                ...
# 75               uttaranchal/2018-05-01/BA2--136-2017
# 76  www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 77  judis.nic.in/2000-05-12/P.  SARATHY Vs. STATE ...
# 78                    delhi/2011-11-04/ITA--1110-2006
# 79  judis.nic.in/1978-12-13/BISWANATH PRASAD RADHE...
#
#                                                   doc  numcites  ...  \
# 0   <div class="docsource_main">Supreme Court of I...        43  ...
# 1   <div class="docsource_main">Supreme Court of I...        22  ...
# 2   <div class="docsource_main">Supreme Court of I...        10  ...
# 3   <div class="docsource_main">Supreme Court of I...        11  ...
# 4   <div class="docsource_main">Supreme Court of I...         8  ...
# ..                                                ...       ...  ...
# 75  <div class="docsource_main">Uttaranchal High C...         2  ...
# 76  <div class="docsource_main">Bombay High Court<...         9  ...
# 77  <div class="docsource_main">Supreme Court of I...        12  ...
# 78  <div class="docsource_main">Delhi High Court</...        11  ...
# 79  <div class="docsource_main">Supreme Court of I...        12  ...
#
#     covertitles                                                url showurl  \
# 0            []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
# 1            []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
# 2            []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
# 3            []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
# 4            []                                               None    True
# ..          ...                                                ...     ...
# 75           []  http://lobis.nic.in/ddir/uhc/VKB/judgement/08-...   False
# 76           []                                               None    True
# 77           []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
# 78           []  http://lobis.nic.in/dhc/RAS/judgement/05-11-20...    True
# 79           []  http://judis.nic.in/supremecourt/imgst.aspx?fi...    True
#
#                  docsource covers  \
# 0   Supreme Court of India     []
# 1   Supreme Court of India     []
# 2   Supreme Court of India     []
# 3   Supreme Court of India     []
# 4   Supreme Court of India     []
# ..                     ...    ...
# 75  Uttarakhand High Court     []
# 76       Bombay High Court     []
# 77  Supreme Court of India     []
# 78        Delhi High Court     []
# 79  Supreme Court of India     []
#
#                                              citeList  \
# 0   [{'tid': 1569253, 'title': 'The Indian Penal C...
# 1   [{'tid': 1712542, 'title': 'Article 226 in The...
# 2   [{'tid': 1210757, 'title': 'The Insurance (Ame...
# 3   [{'tid': 1210757, 'title': 'The Insurance (Ame...
# 4   [{'tid': 1974480, 'title': 'Section 30 in The ...
# ..                                                ...
# 75  [{'tid': 455468, 'title': 'Section 307 in The ...
# 76  [{'tid': 1965344, 'title': 'The Information Te...
# 77  [{'tid': 1692639, 'title': 'the Delhi Special ...
# 78  [{'tid': 1118061, 'title': 'Commissioner Of In...
# 79  [{'tid': 1195137, 'title': 'Section 26 in the ...
#
#                                           citedbyList    divtype  \
# 0   [{'tid': 172707473, 'title': 'Udai Bhan vs Sta...  judgments
# 1   [{'tid': 389038, 'title': 'Rajni vs Union Of I...  judgments
# 2   [{'tid': 1602266, 'title': 'Satish Chandra vs ...  judgments
# 3   [{'tid': 1937188, 'title': 'M/S.A.G.M.Construc...  judgments
# 4   [{'tid': 909652, 'title': 'Champaklal Ganeshma...  judgments
# ..                                                ...        ...
# 75                                                 []  judgments
# 76  [{'tid': 162638144, 'title': 'Beyond Dreams En...  judgments
# 77  [{'tid': 1382757, 'title': 'Rishi Cement Compa...  judgments
# 78  [{'tid': 34771314, 'title': 'Kansai Nerolac Pa...  judgments
# 79  [{'tid': 30010260, 'title': 'Galatea Ltd vs Di...  judgments
#
#                                             relatedqs courtcopy
# 0   [{'value': '188', 'formInput': '188'}, {'value...      True
# 1   [{'value': 'writ citedby:452476', 'formInput':...      True
# 2   [{'value': 'order viii', 'formInput': 'order%2...      True
# 3   [{'value': 'order 21 ', 'formInput': 'order%20...      True
# 4   [{'value': 'baburao', 'formInput': 'baburao'},...     False
# ..                                                ...       ...
# 75                                                NaN      True
# 76  [{'value': 'copyright', 'formInput': 'copyrigh...     False
# 77  [{'value': 'tamil nadu shops', 'formInput': 't...      True
# 78  [{'value': 'software', 'formInput': 'software'...      True
# 79  [{'value': 'invention', 'formInput': 'inventio...      True
#
# [80 rows x 21 columns]

# %%
X.to_csv("First80.csv",index=False)

# %%
df_with_tid_doc = pd.DataFrame(columns = ["DOC_ID","CONTENT"])
df_with_tid_doc["DOC_ID"] = X["tid"]
df_with_tid_doc["CONTENT"] = X["doc"]

# %%
h = html2text.HTML2Text()
h.ignore_links = True

# %%
#save html files

data = pd.read_csv("First80.csv")

for i in range(data.shape[0]):
    f = open("html_files/"+str(int(data.iloc[i,0]))+".html","w+",encoding="utf-8")
    f.write(data.iloc[i,8])
