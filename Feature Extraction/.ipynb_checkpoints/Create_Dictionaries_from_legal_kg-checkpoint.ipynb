# %%
import pandas as pd
import numpy as np
import os
import re
import json

# %%
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')

# %%
for line in legal_kg.readlines()[:5]:
    print(line.split('\t'))
# Out:
# ['6406437', 'organization', 'Competition Commission of India.Shri\n']
# ['6406437', 'organization', 'Ghaziabad Development Authority\n']
# ['6406437', 'organization', 'GDA\n']
# ['6406437', 'organization', 'Uttar Pradesh Opposite Party\n']
# ['6406437', 'organization', 'CORAM\n']

# %%
org_dict = {}
law = {}
person = {}
norp = {}
location = {}
language = {}
city = {}

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'country':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    country[temp[i]] = count
    count = count + 1

# %%
country
# Out:
# {'kingdom of saudi arabia': 1,
#  'Romania': 2,
#  'Germany': 3,
#  'Paraguay': 4,
#  'Iraq': 5,
#  'Albania': 6,
#  'Niger': 7,
#  'india saudia': 8,
#  'Guyana': 9,
#  'india ireland': 10,
#  'Spain': 11,
#  'nepal': 12,
#  'ksa': 13,
#  'UK': 14,
#  'india singapore': 15,
#  'Uruguay': 16,
#  'Dominican Republic': 17,
#  'Antigua and Barbuda': 18,
#  'india usa': 19,
#  'Tanzania': 20,
#  'ph': 21,
#  'Rhodesia': 22,
#  'Finland': 23,
#  'uk': 24,
#  'Austria': 25,
#  'Netherlands': 26,
#  'Philippines': 27,
#  'jamaica': 28,
#  'Vietnam': 29,
#  'Nicaragua': 30,
#  'Ireland': 31,
#  'Puerto Rico': 32,
#  'Kuwait': 33,
#  'Seychelles': 34,
#  'hindustan': 35,
#  'China': 36,
#  'u.s.a': 37,
#  'Tunisia': 38,
#  'usa': 39,
#  'india saudi arabia': 40,
#  'Portugal': 41,
#  'UAE': 42,
#  'Belarus': 43,
#  'saudia': 44,
#  'champa': 45,
#  'india finland': 46,
#  'Bhutan': 47,
#  'Belgium': 48,
#  'Yugoslavia': 49,
#  'india america': 50,
#  'South Korea': 51,
#  'Maldives': 52,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'organization':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    org_dict[temp[i]] = count
    count = count + 1

# %%
org_dict
# Out:
# {'asansol': 1,
#  'Singer Manufacturing Company': 2,
#  'Intex Rates': 3,
#  'U O I.': 4,
#  'Court of Queen': 5,
#  '1 m/s suri engineers pvt ltd.': 6,
#  'an international magazine': 7,
#  'ajo': 8,
#  'no.76/86': 9,
#  'indo nippon chemicals co. ltd.': 10,
#  'the bombay h. c.': 11,
#  'HCL Corporation': 12,
#  'Gokulananda Jena': 13,
#  'jp application no.2000-570771': 14,
#  '‗idsa': 15,
#  'Hakes': 16,
#  'virginia89': 17,
#  'Committee of Copyright': 18,
#  'the pu of the outside party': 19,
#  'R&D Institute': 20,
#  'santosh starch products': 21,
#  'the u.s. congress': 22,
#  'National.Consumer Disputes Redressal Commission': 23,
#  'City Civil Court.Appeal': 24,
#  'societe generale global solutions centre pvt.ltd': 25,
#  'Damodarasamy Naidu & Bros': 26,
#  'Bank Disputes': 27,
#  'subba 736 rao j. in dwarkanath v. ito': 28,
#  'Paun & Paum Chemicals': 29,
#  'Kerala State Gazette': 30,
#  'Warner Hindusthan Ltd': 31,
#  'the discom tangedco': 32,
#  'allergan': 33,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'location':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    location[temp[i]] = count
    count = count + 1

# %%
location
# Out:
# {'asansol': 1,
#  '36219': 2,
#  'Genevo': 3,
#  'Adchini': 4,
#  'gift-tax': 5,
#  'Police Laboratory': 6,
#  'the middle- east': 7,
#  'c.ce': 8,
#  'laghu': 9,
#  'Tri': 10,
#  'ayodhya enclave': 11,
#  'deft.': 12,
#  'h.p': 13,
#  'bhagwant singh': 14,
#  'saunders': 15,
#  'nilanwali': 16,
#  'alibaugh': 17,
#  '18076': 18,
#  '10893': 19,
#  'fairbanks': 20,
#  'Gulf': 21,
#  'kerala-686 001': 22,
#  'Himachal Pradesh': 23,
#  'Railway Station': 24,
#  '15653': 25,
#  '18035': 26,
#  'semayne': 27,
#  'bombay high sea': 28,
#  'India.in': 29,
#  'haldia': 30,
#  'shambhu nath sarkar': 31,
#  'Jones-Shipman': 32,
#  'ratilal': 33,
#  '84919': 34,
#  'Vinca Further': 35,
#  'keshav singhl2': 36,
#  'khumalo': 37,
#  'seshagiri': 38,
#  'Parimoo': 39,
#  'Gokhla': 40,
#  'bane4alo=re south': 41,
#  'Suit': 42,
#  'ranchi region': 43,
#  'boili': 44,
#  'uopllc': 45,
#  'Patna': 46,
#  'new bikanerwala': 47,
#  'Yatra': 48,
#  'Tihar Jail': 49,
#  'Encyclopadeia Britannica': 50,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'person':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    person[temp[i]] = count
    count = count + 1

# %%
person
# Out:
# {'asansol': 1,
#  'yusuf rawther v. sowramma47': 2,
#  'singh hoon': 3,
#  'ayub abdul razak memon': 4,
#  'allama ibn qudama': 5,
#  'lo dh vksj': 6,
#  'jeswantrai manilal akhaney': 7,
#  'v. lfqrnr&1rars': 8,
#  'shri g.s. jetly': 9,
#  'lord wrights': 10,
#  'pranoy roy': 11,
#  'devika biswas': 12,
#  'shri nagi reddy': 13,
#  'm. parvathamma': 14,
#  'chacko': 15,
#  'bachharaj plots': 16,
#  'sh. harpreet ajmani': 17,
#  'bhagwant kishore joshi': 18,
#  'byron d. ball': 19,
#  'p choudary': 20,
#  'saunders': 21,
#  'bhagwant singh': 22,
#  'r dayal': 23,
#  'mohmed shahid nizamuddin qureshi': 24,
#  'k. roy': 25,
#  'purushothama kurup': 26,
#  'y v. chandrachud': 27,
#  'rajev chaudharys': 28,
#  'rajendra nath mukherjee': 29,
#  'sudhansu jyoti mukhopadhaya': 30,
#  'p.k. misra': 31,
#  'm. k. garg': 32,
#  'ellie lilly': 33,
#  'shri k.s. rathore': 34,
#  'p.k.k. raman nair': 35,
#  'spanglish': 36,
#  'fairbanks': 37,
#  'safema': 38,
#  'h.c. bhasin': 39,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'norp':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    norp[temp[i]] = count
    count = count + 1

# %%
norp
# Out:
# {'shia muslims': 1,
#  'chaturvarnya': 2,
#  'pracharak': 3,
#  'chyawanprash': 4,
#  'sivaijamabandi': 5,
#  'stridhanam': 6,
#  's.': 7,
#  'bishops': 8,
#  'non-aryan': 9,
#  'indo canadian': 10,
#  'bhumidar': 11,
#  'latin': 12,
#  'karnavan': 13,
#  'pattadars': 14,
#  'indias': 15,
#  'transgender': 16,
#  'effected': 17,
#  'parsees': 18,
#  'socialist': 19,
#  'secular': 20,
#  'mohomedan': 21,
#  'kapalic': 22,
#  'germanic': 23,
#  'italian - german': 24,
#  'vishwanath': 25,
#  'muhammadan': 26,
#  'indian muslim': 27,
#  'brahmins': 28,
#  'vrindavanam': 29,
#  'non- indian': 30,
#  'educationist': 31,
#  'communism': 32,
#  'p.b.': 33,
#  'maiurayan': 34,
#  'devadasis': 35,
#  'sitagliptin': 36,
#  'samajvadi': 37,
#  'tarwad': 38,
#  'sankalchand': 39,
#  'caste hindu': 40,
#  'marwaris': 41,
#  'aboiltionists': 42,
#  'eastern indian': 43,
#  'presiden': 44,
#  'south african': 45,
#  'j.': 46,
#  'poona': 47,
#  'kashmiri': 48,
#  'frensh': 49,
#  'dekkhan': 50,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'law':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    law[temp[i]] = count
    count = count + 1

# %%
law
# Out:
# {'application no. 106': 1,
#  'madras act viii of 1949': 2,
#  's.l. kapoor v/s jagmohan writ appeal nos.92/2014': 3,
#  'u/s 92ca of the act': 4,
#  's.89 of the bombay prohibition act': 5,
#  'scr 501': 6,
#  'section 33 of the additional duties act': 7,
#  'clause 9 of the 2018 arbitration agreement': 8,
#  'entry 33 of list 11 to the seventh schedule of the constitution': 9,
#  'section 31 and 3 clause ii of sub- section 1 of section 32': 10,
#  'the section of 115jb of the act': 11,
#  'explanation 2 to clause vi of section 91 of the income-tax act': 12,
#  'the act or india-us tax treaty': 13,
#  'section 2 b of the act': 14,
#  'the plain provisions of the rules': 15,
#  'sections 94 and 96 of the code of criminal procedure': 16,
#  'maru ram v. union of india6o': 17,
#  'the m.v. act': 18,
#  'section 72 railways act 1890': 19,
#  'section 17 of the act of 1894': 20,
#  'paragraph 5 of article 5': 21,
#  'the miscellaneous order 54/98-c': 22,
#  'section 43 rule 1': 23,
# ...

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'language':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    language[temp[i]] = count
    count = count + 1

# %%
language
# Out:
# {'bollywood': 1,
#  'norse': 2,
#  'commonwealth': 3,
#  'oxford': 4,
#  'tamil': 5,
#  'greek': 6,
#  'german': 7,
#  'devnagri': 8,
#  'sanskrit': 9,
#  'arabic': 10,
#  'nepali': 11,
#  'language': 12,
#  'telugu': 13,
#  'a.nos.1554': 14,
#  'bengali': 15,
#  'india\x14': 16,
#  'russian': 17,
#  'spanish': 18,
#  'devanagri': 19,
#  'italian': 20,
#  'malayalam': 21,
#  'english': 22,
#  'korean': 23,
#  'dictionary': 24,
#  'grammar': 25,
#  'bangla': 26,
#  '50': 27,
#  'devanagari': 28,
#  'latin': 29,
#  'vernacular': 30,
#  'punjabi': 31,
#  'kannada': 32,
#  'persian': 33,
#  'anglo-norman': 34,
#  'gujarati': 35,
#  'dominicans': 36,
#  'urdu': 37,
#  'french': 38,
#  'indian': 39,
#  'hindi': 40,
#  'oriental': 41,
#  'marathi': 42,
#  'hindustani': 43,
#  'ayurvedic': 44}

# %%
count = 1
temp = []
legal_kg = open('legalkg_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'city':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    city[temp[i]] = count
    count = count + 1

# %%
city
# Out:
# {'Detroit': 1,
#  'Satara': 2,
#  'Khammam': 3,
#  'ALLAHABAD': 4,
#  'Mountain View.': 5,
#  'Kampar': 6,
#  'buffalo': 7,
#  'Bihar': 8,
#  'Sachin': 9,
#  'Aylesbury': 10,
#  'Madurai': 11,
#  'Tel Aviv': 12,
#  'Helena': 13,
#  'Somerville': 14,
#  'Azamgarh': 15,
#  'chandigarh': 16,
#  'Coimbatore': 17,
#  'Nalgonda': 18,
#  'Kadur': 19,
#  'Heathrow': 20,
#  'aua': 21,
#  'Atchison': 22,
#  'PONDICHERRY': 23,
#  'Mori': 24,
#  'Jodhpur': 25,
#  'Mahad': 26,
#  'Baripada': 27,
#  'Fort William': 28,
#  'Highland': 29,
#  'Arya': 30,
#  'Patna': 31,
#  'Irinjalakuda': 32,
#  'Roman': 33,
#  'Jaisalmer': 34,
#  'Meghraj': 35,
#  'Mhasla': 36,
#  'Golden Temple': 37,
#  'Vijayawada': 38,
#  'Fountain': 39,
#  'Bangaon': 40,
#  'Mohan': 41,
#  'Los.Angeles': 42,
#  'Mirzapur': 43,
#  'Chamba': 44,
#  'Marlborough': 45,
#  'Shrigonda': 46,
#  'Belfast': 47,
#  'Abu Dhabi': 48,
#  'Liverpool Bay': 49,
#  'Denver': 50,
#  'Rome': 51,
#  'Falmouth': 52,
#  'Barkot': 53,
#  'Dehu': 54,
# ...

# %%
count = len(org_dict)
temp = []
legal_kg = open('legalkg2_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'organization':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    org_dict[temp[i]] = count
    count = count + 1

# %%
org_dict
# Out:
# {'asansol': 1,
#  'Singer Manufacturing Company': 2,
#  'Intex Rates': 3,
#  'U O I.': 4,
#  'Court of Queen': 5,
#  '1 m/s suri engineers pvt ltd.': 6,
#  'an international magazine': 7,
#  'ajo': 8,
#  'no.76/86': 9,
#  'indo nippon chemicals co. ltd.': 10,
#  'the bombay h. c.': 11,
#  'HCL Corporation': 12,
#  'Gokulananda Jena': 13,
#  'jp application no.2000-570771': 14,
#  '‗idsa': 15,
#  'Hakes': 16,
#  'virginia89': 17,
#  'Committee of Copyright': 18,
#  'the pu of the outside party': 19,
#  'R&D Institute': 20,
#  'santosh starch products': 21,
#  'the u.s. congress': 22,
#  'National.Consumer Disputes Redressal Commission': 23,
#  'City Civil Court.Appeal': 24,
#  'societe generale global solutions centre pvt.ltd': 25,
#  'Damodarasamy Naidu & Bros': 26,
#  'Bank Disputes': 27,
#  'subba 736 rao j. in dwarkanath v. ito': 28,
#  'Paun & Paum Chemicals': 29,
#  'Kerala State Gazette': 30,
#  'Warner Hindusthan Ltd': 31,
#  'the discom tangedco': 32,
#  'allergan': 33,
# ...

# %%
len(org_dict)
# Out:
# 127728

# %%
count = len(location)
temp = []
legal_kg = open('legalkg2_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'location':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    location[temp[i]] = count
    count = count + 1

# %%
len(location)
# Out:
# 24589

# %%
count = len(city)
temp = []
legal_kg = open('legalkg2_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'city':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    city[temp[i]] = count
    count = count + 1

# %%
len(city)
# Out:
# 1259

# %%
count = len(country)
temp = []
legal_kg = open('legalkg2_dataset.txt','r',encoding='utf-8')
for line in legal_kg.readlines():
    arr_line = line.split('\t')
    if arr_line[1] == 'country':
        temp.append(arr_line[2][:-1])
        
temp = list(set(temp))
for i in range(len(temp)):
    country[temp[i]] = count
    count = count + 1

# %%
len(city) , len(country)
# Out:
# (1259, 246)

# %%
oe = pd.read_csv("OE_LABELS.csv", encoding="utf-8")

# %%
len(oe['ORGANIZATION'])
# Out:
# 958

# %%
'LAW', 'INFRINGEMENT', 'PERSON', 'NATION/RELIGIOUS/POL_GROUP', 'GEOGRAPHICAL_LOC', 'LANGUAGE', 'LOCATION_STRUCTURE', 'LOCATION', 'CONTACTNAME', 'ORGANIZATION', 'ORGANIZATION2', 'GEOGRAPHY2', 'DATETIME', 'PERCENT'
# Out:
# ('LAW',
#  'INFRINGEMENT',
#  'PERSON',
#  'NATION/RELIGIOUS/POL_GROUP',
#  'GEOGRAPHICAL_LOC',
#  'LANGUAGE',
#  'LOCATION_STRUCTURE',
#  'LOCATION',
#  'CONTACTNAME',
#  'ORGANIZATION',
#  'ORGANIZATION2',
#  'GEOGRAPHY2',
#  'DATETIME',
#  'PERCENT')

# %% [markdown]
# 1. Read OE_labels line by line
# 2. Pick the tid
# 3. Pass the tid to function with the dictionary and column name
# 4. Function will search the file for the tid and the corresponding dictionary token
# 5. Store the tokens in an array
# 6. Find the max occuring token and find its index from the dictionary
# 7. Return the index
