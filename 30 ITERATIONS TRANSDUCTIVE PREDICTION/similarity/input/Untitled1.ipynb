# %%
import pandas as pd
import numpy as np

# %%
oe = pd.read_csv("OE_LABELS.csv")

# %%
ner = pd.read_csv("NER_FEATURES.csv")

# %%
oe
# Out:
#            tid  LEGAL_SCJUDGE  LEGAL_DESIGN  LEGAL_GEN  LEGAL_PATENT  \
# 0       100123              0             6         17             0
# 1      1001948              0             4         31             2
# 2      1006468              0             4         31             0
# 3      1006709              0             0         22             0
# 4      1007946              0             0         17             0
# ...        ...            ...           ...        ...           ...
# 1033  81162651              0             6         26             0
# 1034   8433581              0             8          2             0
# 1035    850381              0             4         31             3
# 1036  94612663              0             4         31             0
# 1037  98291024              0             0         31             0
#
#       LEGAL_TRADEMARK  LEGAL_COPYRIGHT  LEGAL_RESERVATION_CATEGORY  \
# 0                   0                0                           0
# ...

# %%
ner
# Out:
#             tid    LAW  INFRINGEMENT  PERSON  NATION/RELIGIOUS/POL_GROUP  \
# 0       1004544      0             0       0                           0
# 1     102042281      0             1       0                           0
# 2       1025815      0             1       0                           0
# 3       1062207      0             1       0                           0
# 4     106681665      0             1       0                           0
# ...         ...    ...           ...     ...                         ...
# 1033   99622088  58915             0    8817                         868
# 1034     996328  47882             0   32717                         730
# 1035     996348  61064             0   19129                        1144
# 1036   99670896  56497             0   40157                           0
# 1037     997135  37952             0    4505                           0
#
#       GEOGRAPHICAL_LOC  LANGUAGE  LOCATION_STRUCTURE  LOCATION  CONTACTNAME  \
# ...

# %%
oe_t = oe.sort_values(by=['tid'])

# %%
ner_t = ner.sort_values(by=['tid'])

# %%
oe_t
# Out:
#             tid  LEGAL_SCJUDGE  LEGAL_DESIGN  LEGAL_GEN  LEGAL_PATENT  \
# 282        1566              0             7          2             2
# 645        4354              0             7         30             0
# 696        5192              0             6         33             3
# 767        6547              0             7         30             0
# 973       13352              0             4         31             0
# ...         ...            ...           ...        ...           ...
# 1000  192230665              0             4         17             2
# 480   192914986              0             0          0             0
# 485   194456776              0             7         17             0
# 504   198827109              0             0         31             0
# 509   199908142              0             7         31             0
#
#       LEGAL_TRADEMARK  LEGAL_COPYRIGHT  LEGAL_RESERVATION_CATEGORY  \
# ...

# %%
ner_t
# Out:
#            tid    LAW  INFRINGEMENT  PERSON  NATION/RELIGIOUS/POL_GROUP  \
# 375       1566  52476             0    7427                        1033
# 732       4354  73493             0    9487                         267
# 782       5192  72155             0   10253                          41
# 848       6547  68185             0   26578                        1210
# 18       13352      0             0       0                           0
# ..         ...    ...           ...     ...                         ...
# 48   192230665      0             1       0                           0
# 569  192914986      0             0   25976                           0
# 574  194456776  20541             0    5050                        1144
# 593  198827109  69808             0   20021                         931
# 598  199908142  74224             0    4750                           0
#
#      GEOGRAPHICAL_LOC  LANGUAGE  LOCATION_STRUCTURE  LOCATION  CONTACTNAME  \
# ...

# %%
oe_t.to_csv("OE_WITHOUT_NER_SORTED.csv",index=False)

# %%
ner_t.to_csv("OE_NER_SORTED.csv",index=False)

# %%
df3 = pd.merge(oe_t, ner_t, on = 'tid')

# %%
df3
# Out:
#             tid  LEGAL_SCJUDGE  LEGAL_DESIGN  LEGAL_GEN  LEGAL_PATENT  \
# 0          1566              0             7          2             2
# 1          4354              0             7         30             0
# 2          5192              0             6         33             3
# 3          6547              0             7         30             0
# 4         13352              0             4         31             0
# ...         ...            ...           ...        ...           ...
# 1033  192230665              0             4         17             2
# 1034  192914986              0             0          0             0
# 1035  194456776              0             7         17             0
# 1036  198827109              0             0         31             0
# 1037  199908142              0             7         31             0
#
#       LEGAL_TRADEMARK  LEGAL_COPYRIGHT  LEGAL_RESERVATION_CATEGORY  \
# ...

# %%
df3.columns
# Out:
# Index(['tid', 'LEGAL_SCJUDGE', 'LEGAL_DESIGN', 'LEGAL_GEN', 'LEGAL_PATENT',
#        'LEGAL_TRADEMARK', 'LEGAL_COPYRIGHT', 'LEGAL_RESERVATION_CATEGORY',
#        'LEGAL_CRIMINAL_PROCEDURE', 'LEGAL_ENTITY', 'COPYRIGHT_ACT',
#        'PATENTS_ACT', 'DESIGNS_ACT', 'INFORMATION_TECHNOLOGY_ACT',
#        'TRADEMARK_ACT', 'LAW', 'INFRINGEMENT', 'PERSON',
#        'NATION/RELIGIOUS/POL_GROUP', 'GEOGRAPHICAL_LOC', 'LANGUAGE',
#        'LOCATION_STRUCTURE', 'LOCATION', 'CONTACTNAME', 'ORGANIZATION',
#        'ORGANIZATION2', 'GEOGRAPHY2', 'DATETIME', 'PERCENT'],
#       dtype='object')

# %%
df3.to_csv("FINAL_OE_LABELS_WITH_NER.csv",index=False)

# %%
int(100123.0)
# Out:
# 100123

# %%
import pandas as pd

# %%
f = pd.read_csv("BERT_FEATURES_AVERAGE.csv")
for i in range(f.shape[0]):
    x = int(f.iloc[i,0])
    print(x)
    f.iloc[i,0] = int(x)

f.to_csv("BERT_FEATURES.csv",index=False)
# Out:
# 100123
# 1001948
# 1006468
# 1006709
# 1007946
# 101008236
# 1011356
# 1012649
# 1013766
# 1014138
# 1019490
# 1022090
# 1022584
# 1023674
# 10239019
# 1024124
# 102653512
# 102852
# 102886851
# 103057287
# 1030976
# 1033637
# 1033812
# 103434922
# 1035346
# 103561
# 1035719
# 1038563
# 104312764
# 104313664
# 104377
# 104810373
# 1048632
# 104935066
# 1052178
# 1053542
# 1056935
# 105936170
# 1062099
# 1073828
# 107853771
# 108020655
# 108509106
# 1086058
# 1092394
# 109700315
# 1097490
# 1097981
# 1098305
# 109874394
# 1099140
# 1102062
# 1103984
# 1104087
# 1104701
# 1105134
# 1106747
# 110813550
# 1110013
# 1114158
# 1115541
# 111777378
# 1120137
# 1120277
# 1120373
# 1121229
# 112850760
# 112896520
# 112937069
# 1129833
# 1130742
# 1131957
# 1132299
# 1132362
# 1134429
# 1134697
# 1136663
# 1136885
# 113963352
# 1147125
# 1147963
# 1149874
# 1151918
# 1152518
# 1154981
# 1155640
# 1156538
# 115701246
# 115718142
# 1159790
# 1163546
# 116548206
# 1165503
# 1166220
# 1168060
# ...
