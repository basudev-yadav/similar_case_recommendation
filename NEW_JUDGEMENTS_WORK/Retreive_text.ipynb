# %%
import pandas as pd
import numpy as np
import re
import html2text
import requests
from urllib.parse import urljoin
from datetime import datetime
import pandas as pd

# %%
#define the IndianKanoon API class
class IndianKanoon:
  """
    https://github.com/aishik-pyne/kanoon
    Search query	https://api.indiankanoon.org/search/?formInput=<query>&pagenum=<pagenum>
    Document	https://api.indiankanoon.org/doc/<docid>/
    Document fragments	https://api.indiankanoon.org/docfragment/<docid>/?formInput=<query>
    Document Metainfo	https://api.indiankanoon.org/docmeta/<docid>/
  """

  def __init__(self):
    self.base_url = "https://api.indiankanoon.org/"
    #self.auth_token is a newly generated token from the IndiaKanoon API website(you have to generate it manually)
    self.auth_token = "9cd44463828341ca7d7401135bf82b1c14520677"
    
    self.headers = {
        'authorization': "Token {}".format(self.auth_token),
        'cache-control': "no-cache",
    }
    self.api_session = requests.Session()
    self.api_session.headers = self.headers

  def search(self, formInput, pagenum=0,
             fromdate=None, todate=None,
             title=None, author=None,
             cite=None, bench=None, maxpages=50):
    #  Creating parameters
    params = {
        'formInput': formInput,
        'pagenum': pagenum,
        'maxpages': maxpages
    }
    if fromdate:
      assert isinstance(fromdate, datetime) 
      params['fromdate'] = fromdate.strftime('%d-%m-&Y')

    if todate:
      assert isinstance(todate, datetime) 
      params['todate'] = todate.strftime('%d-%m-&Y')

    # Making the request
    response = self.api_session.post(
        urljoin(self.base_url, 'search/'), params=params)
    response.raise_for_status()
    return response.json()

  def doc(self, docid):
    response = self.api_session.post(
        urljoin(self.base_url, 'doc/{}/'.format(docid)))
    response.raise_for_status()
    return response.json()

  def docfragment(self, docid, formInput):
    params = {
        'formInput': formInput,
    }
    response = self.api_session.post(
        urljoin(self.base_url, 'docfragment/{}/'.format(docid)), params=params)
    response.raise_for_status()
    return response.json()

  def docmeta(self, docid):
    response = self.api_session.post(
        urljoin(self.base_url, 'docmeta/{}/'.format(docid)))
    response.raise_for_status()
    return response.json()

# %%
#initialize object
ik = IndianKanoon()

# %%
#read the casemine file obtained from the pipeline(contains the judgement and similar judgements along with the links)
df = pd.read_csv('casemine.csv')

# %%
#returns document id from link
def get_id(link):
    regex = re.compile(r'[0-9]+')
    result = regex.search(link)
    
    if(result):
        return result.group()
    else:
        return ""

# %%
#doclink dictionary is used to map judgement name with its ID
doclink = {}

for i in range(df.shape[0]):
    m_j = df.iloc[i,0]
    s_j = df.iloc[i,2]
    m_j_l = df.iloc[i,1]
    s_j_l = df.iloc[i,3]
    
    if m_j not in doclink.keys() and s_j_l != "":
        doclink[m_j] = get_id(str(m_j_l))
    if s_j not in doclink.keys() and m_j_l != "":
        doclink[s_j] = get_id(str(s_j_l))

# %%
doc_with_id = pd.DataFrame(columns=["name","id"])

counter = 0

for i in doclink.keys():
    if doclink[i] != '':
        row = [i , doclink[i]]
        doc_with_id.loc[counter] = row
        counter = counter + 1

# %%
case_with_id = dict(zip(doc_with_id.name,doc_with_id.id))

# %%
case_with_id
# Out:
# {'Wander Ltd. And Another v. Antox India P. Ltd. .': '330608',
#  'Remidex Pharma Private Limited v. Savita Pharmaceuticals P. Ltd': '744316',
#  'Wyeth Holdings Corporation & Anr. v. Burnet Pharmaceuticals (Pvt.) Ltd.': '357841',
#  'Fdc Limited v. Mr. Ajay G. Piramal & Ors': '1004544',
#  'Sun Pharma Laboratories Ltd. v. Intas Pharmaceuticals Limited': '157791679',
#  'Stiefel Laboratories v. Ajanta Pharma Ltd.': '102042281',
#  'S.B.L Limited v. The Himalaya Drug Co.': '615459',
#  'Glaxo Group Ltd. And Another v. Neon Laboratories Ltd.': '663392',
#  'Radico Khaitan Limited v. Brima Sagar Maharashtra Distilleries Ltd.': '27816811',
#  'L.T. Overseas Ltd. v. Guruji Trading Co.': '1857898',
#  'Hero Honda Motors Ltd. v. Assuramji Scooters': '1375229',
#  'Hero Honda Motors Ltd. v. Raj Scooters': '1375229',
#  'Hero Honda Motors Limited v. Rafiq Memon': '8022081',
#  'Marc Enterprises Pvt. Ltd. v. Victor Industries': '1611564',
#  'Nirog Pharma Pvt. Ltd. v. Umesh Gupta': '125686531',
#  'Indian Performing Right Society Ltd. v. Debashis Patnaik': '1983225',
#  'Haldiram Bhujiawala & Anr. v. Anand Kumar Deepak Kumar & Ors.': '141920684',
#  'Haldiram (India) Private Limited v. Halidram Bhujiawala & Anr': '141920684',
#  'Haldiram Bhujiawala & Anr. v. Anand Kumar Deepak Kumar & Ors. S': '141920684',
#  'Radhika Agro Industries Pvt. Ltd. v. Paawan Agro Foods Ltd': '374690',
#  'Bimal Govindji Shah Trading As Acme Industries v. Panna Lal Chandu Lal': '1460395',
#  'Rakesh Kumar Aggarwal v. Lock & Locking Devices': '1981161',
#  'Visakha Chemicals v. Mala Ram & Sons': '1281453',
#  'Cadila Healthcare Ltd. v. Aureate Healthcare Pvt. Ltd.': '145549327',
#  'Eaton Corporation v. Bch Electric Limited': '112995556'}

# %%
#remove duplicate ids from dictionary

temp = []
res = dict()
for key, val in case_with_id.items():
    if val not in temp:
        temp.append(val)
        res[key] = val

# %%
res
# Out:
# {'Wander Ltd. And Another v. Antox India P. Ltd. .': '330608',
#  'Astrazeneca Uk Ltd. v. Orchid Chemicals & Pharmaceuticals Ltd.': '1509899',
#  'S.M Dyechem Ltd. v. Cadbury (India) Ltd. .': '1025815',
#  'Veerumal Praveen Kumar v. Needle Industries (India) Ltd. And Anr.': '1945028',
#  'N.R Dongre And Others v. Whirlpool Corporation And Another': '850381',
#  'Pfizer Products Inc. v. Rajesh Chopra': '1674695',
#  'Mahendra & Mahendra Paper Mills Ltd. v. Mahindra & Mahindra Ltd. .': '67204010',
#  'Lupin Limited v. Johnson & Johnson': '19267666',
#  'Cadila Health Care Ltd. v. Cadila Pharmaceuticals Ltd. .': '1114158',
#  'Purshottam Vishandas Raheja And Another v. Shrichand Vishandas Raheja (Dead) Through Lrs. And Others': '81162651',
#  'Fedders North American v. Show Line': '1269197',
#  'Ramesh Khatanmal Lulla v. Mohammad Yusuf Abdul Gaffar': '70200400',
#  'Indian Performing Right Society Ltd. v. Debashis Patnaik': '1983225',
#  'Haldiram Bhujiawala & Anr. v. Anand Kumar Deepak Kumar & Ors.': '141920684',
#  'Radhika Agro Industries Pvt. Ltd. v. Paawan Agro Foods Ltd': '374690',
#  'Bimal Govindji Shah Trading As Acme Industries v. Panna Lal Chandu Lal': '1460395',
#  'Rakesh Kumar Aggarwal v. Lock & Locking Devices': '1981161',
#  'Visakha Chemicals v. Mala Ram & Sons': '1281453',
#  'Cadila Healthcare Ltd. v. Aureate Healthcare Pvt. Ltd.': '145549327',
#  'Eaton Corporation v. Bch Electric Limited': '112995556'}

# %%
docs = []

count = 0
for i in res.values():
    docs.append(ik.doc(docid=str(i)))
    print("FILE NUMBER: ",(count+1))
    count = count + 1
# Out:
# FILE NUMBER:  1
# FILE NUMBER:  2
# FILE NUMBER:  3
# FILE NUMBER:  4
# FILE NUMBER:  5
# FILE NUMBER:  6
# FILE NUMBER:  7
# FILE NUMBER:  8
# FILE NUMBER:  9
# FILE NUMBER:  10
# FILE NUMBER:  11
# FILE NUMBER:  12
# FILE NUMBER:  13
# FILE NUMBER:  14
# FILE NUMBER:  15
# FILE NUMBER:  16
# FILE NUMBER:  17
# FILE NUMBER:  18
# FILE NUMBER:  19
# FILE NUMBER:  20
# FILE NUMBER:  21
# FILE NUMBER:  22
# FILE NUMBER:  23
# FILE NUMBER:  24
# FILE NUMBER:  25
# FILE NUMBER:  26
# FILE NUMBER:  27
# FILE NUMBER:  28
# FILE NUMBER:  29
# FILE NUMBER:  30
# FILE NUMBER:  31
# FILE NUMBER:  32
# FILE NUMBER:  33
# FILE NUMBER:  34
# FILE NUMBER:  35
# FILE NUMBER:  36
# FILE NUMBER:  37
# FILE NUMBER:  38
# FILE NUMBER:  39
# FILE NUMBER:  40
# FILE NUMBER:  41
# FILE NUMBER:  42
# FILE NUMBER:  43
# FILE NUMBER:  44
# FILE NUMBER:  45
# FILE NUMBER:  46
# FILE NUMBER:  47
# FILE NUMBER:  48
# FILE NUMBER:  49
# FILE NUMBER:  50
# FILE NUMBER:  51
# FILE NUMBER:  52
# FILE NUMBER:  53
# FILE NUMBER:  54
# FILE NUMBER:  55
# FILE NUMBER:  56
# FILE NUMBER:  57
# FILE NUMBER:  58
# FILE NUMBER:  59
# FILE NUMBER:  60
# FILE NUMBER:  61
# FILE NUMBER:  62
# FILE NUMBER:  63
# FILE NUMBER:  64
# FILE NUMBER:  65
# FILE NUMBER:  66
# FILE NUMBER:  67
# FILE NUMBER:  68
# FILE NUMBER:  69
# FILE NUMBER:  70
# FILE NUMBER:  71
# FILE NUMBER:  72
# FILE NUMBER:  73
# FILE NUMBER:  74
# FILE NUMBER:  75
# FILE NUMBER:  76
# FILE NUMBER:  77
# FILE NUMBER:  78
# FILE NUMBER:  79
# FILE NUMBER:  80
# FILE NUMBER:  81
# FILE NUMBER:  82
# FILE NUMBER:  83
# FILE NUMBER:  84
# FILE NUMBER:  85
# FILE NUMBER:  86
# FILE NUMBER:  87
# FILE NUMBER:  88
# FILE NUMBER:  89
# FILE NUMBER:  90
# FILE NUMBER:  91
# FILE NUMBER:  92
# FILE NUMBER:  93
# FILE NUMBER:  94
# FILE NUMBER:  95
# FILE NUMBER:  96

# %%
ik_result = pd.DataFrame.from_dict(docs)

# %%
ik_result
# Out:
#             tid covertids publishdate firstname secondname        lastname  \
# 0      330608.0        []  1990-04-26         o       None  venkatachaliah
# 1     1509899.0        []  2006-05-16         a       None           kumar
# 2     1025815.0        []  1999-08-24         a       None         kapadia
# 3     1945028.0        []  2001-08-24         s          k            kaul
# 4      850381.0        []  1995-04-21         a          d           singh
# ..          ...       ...         ...       ...        ...             ...
# 91    1460395.0        []  1997-04-24         m       None          sharma
# 92    1981161.0        []  1996-11-08         k       None     ramamoorthy
# 93    1281453.0        []  2006-02-01         s          k            kaul
# 94  145549327.0        []  2012-07-30         m       None           singh
# 95  112995556.0        []  2013-07-01         m       None           singh
#
#                                                 title  \
# 0   Wander Ltd. And Anr. vs Antox India P. Ltd. on...
# 1   Astrazeneca Uk Ltd. And Anr. vs Orchid Chemica...
# 2   Cadbury India Limited vs Sm Dyechem Limited on...
# 3   M/S. Veerumal Praveen Kumar vs M/S. Needle Ind...
# 4   N.R. Dongre And Ors. vs Whirlpool Corporation ...
# ..                                                ...
# 91  Bimal Govindji Shah vs Panna Lal Chandu Lal on...
# 92  Rakesh Kumar Aggarwal vs Locks & Locking Devic...
# 93  Visakha Chemicals vs Mala Ram And Sons on 1 Fe...
# 94  Cadila Healthcare Ltd. vs Aureate Healthcare P...
# 95  Eaton Corporation & Anr. vs Bch Electric Limit...
#
#                                              filename  \
# 0   www.manupatra.co.in/NXT/gateway.dll/sc/1980-20...
# 1   www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 2   www.manupatra.co.in/NXT/gateway.dll/HighCourt3...
# 3   www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 4   www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# ..                                                ...
# 91  www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 92  www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 93  www.manupatra.co.in/NXT/gateway.dll/highcourt1...
# 94                      delhi/2012-07-30/IA--800-2011
# 95                  delhi/2013-07-01/CS(OS)--156-2012
#
#                                                   doc  numcites  ...  \
# 0   <div class="docsource_main">Supreme Court of I...       5.0  ...
# 1   <div class="docsource_main">Delhi High Court</...      45.0  ...
# 2   <div class="docsource_main">Gujarat High Court...      20.0  ...
# 3   <div class="docsource_main">Delhi High Court</...      26.0  ...
# 4   <div class="docsource_main">Delhi High Court</...      24.0  ...
# ..                                                ...       ...  ...
# 91  <div class="docsource_main">Delhi High Court</...      14.0  ...
# 92  <div class="docsource_main">Delhi High Court</...       8.0  ...
# 93  <div class="docsource_main">Delhi High Court</...      13.0  ...
# 94  <div class="docsource_main">Delhi High Court</...      15.0  ...
# 95  <div class="docsource_main">Delhi High Court</...      20.0  ...
#
#                                                   url showurl  \
# 0                                                None    True
# 1                                                None    True
# 2                                                None    True
# 3                                                None    True
# 4                                                None    True
# ..                                                ...     ...
# 91                                               None    True
# 92                                               None    True
# 93                                               None    True
# 94  http://lobis.nic.in/dhc/MAN/judgement/30-07-20...    True
# 95  http://lobis.nic.in/dhc/MAN/judgement/02-07-20...    True
#
#                  docsource covers  \
# 0   Supreme Court of India     []
# 1         Delhi High Court     []
# 2       Gujarat High Court     []
# 3         Delhi High Court     []
# 4         Delhi High Court     []
# ..                     ...    ...
# 91        Delhi High Court     []
# 92        Delhi High Court     []
# 93        Delhi High Court     []
# 94        Delhi High Court     []
# 95        Delhi High Court     []
#
#                                              citeList  \
# 0   [{'tid': 1891720, 'title': 'the Drugs and Cosm...
# 1   [{'tid': 1331119, 'title': 'Section 124 in The...
# 2   [{'tid': 1353758, 'title': 'The Companies Act,...
# 3   [{'tid': 931654, 'title': 'the Designs Act, 20...
# 4   [{'tid': 1664136, 'title': 'Section 27(2) in T...
# ..                                                ...
# 91  [{'tid': 1365016, 'title': 'Section 27(2) in T...
# 92  [{'tid': 1005493, 'title': 'The Trade And Merc...
# 93  [{'tid': 1098485, 'title': 'Section 45 in the ...
# 94  [{'tid': 84096, 'title': 'Section 29 in The Tr...
# 95  [{'tid': 1853612, 'title': 'Section 7 in The T...
#
#                                           citedbyList    divtype  \
# 0   [{'tid': 1960724, 'title': 'Cadbury Ltd. And 2...  judgments
# 1   [{'tid': 69071842, 'title': 'Data Infosys Ltd....  judgments
# 2   [{'tid': 1965135, 'title': 'Torrent Pharmaceut...  judgments
# 3   [{'tid': 63429287, 'title': 'Radico Khaitan Lt...  judgments
# 4   [{'tid': 109727818, 'title': 'Toyota Jidosha K...  judgments
# ..                                                ...        ...
# 91  [{'tid': 26238666, 'title': 'Rubaljit Singh vs...  judgments
# 92  [{'tid': 1235568, 'title': 'Century Continuous...  judgments
# 93  [{'tid': 1209615, 'title': 'Alkem Laboratories...  judgments
# 94  [{'tid': 97049398, 'title': 'Charak Pharma Pvt...  judgments
# 95  [{'tid': 14309610, 'title': 'Bch Electric Limi...  judgments
#
#                                             relatedqs courtcopy errmsg
# 0   [{'value': 'antox', 'formInput': 'antox'}, {'v...     False    NaN
# 1   [{'value': 'trademark', 'formInput': 'trademar...     False    NaN
# 2   [{'value': 'picnic', 'formInput': 'picnic'}, {...     False    NaN
# 3   [{'value': 'trademark', 'formInput': 'trademar...     False    NaN
# 4   [{'value': 'whirlpool', 'formInput': 'whirlpoo...     False    NaN
# ..                                                ...       ...    ...
# 91  [{'value': 'hardware', 'formInput': 'hardware'...     False    NaN
# 92  [{'value': 'trade mark', 'formInput': 'trade%2...     False    NaN
# 93  [{'value': 'trademark', 'formInput': 'trademar...     False    NaN
# 94  [{'value': 'trademark', 'formInput': 'trademar...      True    NaN
# 95  [{'value': 'trademark', 'formInput': 'trademar...      True    NaN
#
# [96 rows x 22 columns]

# %%
ik_result.to_csv("ikanoon_result.csv",index=False)

# %%
df_with_tid_doc = pd.DataFrame(columns = ["DOC_ID","CONTENT"])
df_with_tid_doc["DOC_ID"] = ik_result["tid"]
df_with_tid_doc["CONTENT"] = ik_result["doc"]

# %%
df_with_tid_doc
# Out:
#          DOC_ID                                            CONTENT
# 0      330608.0  <div class="docsource_main">Supreme Court of I...
# 1     1509899.0  <div class="docsource_main">Delhi High Court</...
# 2     1025815.0  <div class="docsource_main">Gujarat High Court...
# 3     1945028.0  <div class="docsource_main">Delhi High Court</...
# 4      850381.0  <div class="docsource_main">Delhi High Court</...
# ..          ...                                                ...
# 91    1460395.0  <div class="docsource_main">Delhi High Court</...
# 92    1981161.0  <div class="docsource_main">Delhi High Court</...
# 93    1281453.0  <div class="docsource_main">Delhi High Court</...
# 94  145549327.0  <div class="docsource_main">Delhi High Court</...
# 95  112995556.0  <div class="docsource_main">Delhi High Court</...
#
# [96 rows x 2 columns]

# %%
df_with_tid_doc.to_csv("doc_id_with_content.csv",index=False)

# %%
h = html2text.HTML2Text()
h.ignore_links = True

# %%
t = df_with_tid_doc["CONTENT"]
d = df_with_tid_doc["DOC_ID"]

# %%
#get text

for i in range(ik_result.shape[0]):
    text=ik_result.iloc[i,8]
    text = h.handle(str(text))
    if np.isnan(ik_result.iloc[i,0]):
        name = ik_result.iloc[i,6]
    else:
        name = int(ik_result.iloc[i,0])
    f = open("text_files/"+str(name)+".txt",'w+',encoding='utf-8')
    f.write(text)
    f.close()

# %%
#save html files

data = pd.read_csv("ikanoon_result.csv")

for i in range(ik_result.shape[0]):
    f = open("text_files_html/"+str(int(ik_result.iloc[i,0]))+".html","w+",encoding="utf-8")
    f.write(data.iloc[i,8])

# %%
docs = []
name = "139585580"
docs.append(ik.doc(docid=name))
ik_result = pd.DataFrame.from_dict(docs)
text = h.handle(str(ik_result.iloc[0,8]))
f = open("text_files/"+str(int(ik_result.iloc[0,0]))+".txt",'w+',encoding='utf-8')
f.write(text)
f.close()

# %%
ik_result
# Out:
#          tid covertids publishdate firstname secondname lastname  \
# 0  139585580        []  2017-11-28      None       None     None
#
#                                                title  \
# 0  Triumphant Institute Of ... vs Mahesh Yadav & ...
#
#                              filename  \
# 0  delhi/2017-11-28/CS COMM--934-2016
#
#                                                  doc  numcites  numcitedby  \
# 0  <div class="docsource_main">Delhi High Court</...         0           0
#
#   covertitles                                                url  showurl  \
# 0          []  http://lobis.nic.in/ddir/dhc/VJM/judgement/29-...     True
#
#           docsource covers citeList citedbyList    divtype  courtcopy
# 0  Delhi High Court     []       []          []  judgments       True

# %%
ik_result.iloc[0,8]
# Out:
# '<div class="docsource_main">Delhi High Court</div>\n<div class="doc_title">Triumphant Institute Of ... vs Mahesh Yadav &amp; Anr. on 28 November, 2017</div><pre id="pre_1">*            IN THE HIGH COURT OF DELHI AT NEW DELHI\n\n+                   CS(COMM) No. 934/2016 &amp; I.A 10996/2016\n\n%                                                28th November, 2017\n\nTRIUMPHANT INSTITUTE OF MANAGEMENT EDUCATION\nPVT. LTD.                                  ..... Plaintiff\n                 Through: Ms. Bitika Sharma and Mr.\n                          Lakshay Kaushik, Advocates.\n\n                           versus\n\nMAHESH YADAV &amp; ANR.                                      ..... Defendants\n\nCORAM:\nHON\'BLE MR. JUSTICE VALMIKI J.MEHTA\n\nTo be referred to the Reporter or not?\n\nVALMIKI J. MEHTA, J (ORAL)\n\n1.           The present suit is filed by the plaintiff seeking the reliefs\n\nof injunction restraining the defendants from violating the rights in the\n\ntrademark \'T.I.M.E\' (Triumphant Institute of Management Education)\n\nof the plaintiff. Causes of action are also pleaded and reliefs claimed\n\nfor injunction on the basis of the defendants passing off the trademark\n\nof the plaintiff with respect to the services in question. Plaintiff also\n\npleads unfair competition, dilution etc as also seeks reliefs of rendition\n\nof accounts and damages.\n\n\n\n\nCS(COMM) No. 934/2016                                            Page 1 of 4\n 2.           The case of the plaintiff is that plaintiff is the owner of\n\nthe trademark \'T.I.M.E\' and which are initials drawn from the name of\n\nthe plaintiff company which is Triumphant Institute of Management\n\nEducation Pvt. Ltd. Plaintiff pleads that it is engaged in the business\n\nfor providing of services of a coaching institute and training centers\n\nhaving about 244 centers and branches in over 116 cities and towns in\n\nIndia. Plaintiff offers training for national level examinations such as\n\nCAT, Bank, GATE, IIT JEE examination etc. Plaintiff pleads that it\n\nadopted the trademark \'T.I.M.E\' in the year 1992 and thereafter has\n\nbeen regularly using this trademark for coaching services. Plaintiff has\n\ngot registered the trademark as under:-\n\n        S No.   Trademark                 Reg.no/App.No.     Class\n        1.      T.I.M.E Triumphant        1343168            41\n                Institute of Management\n                Education (word mark)\n        2.      T.I.M.E (Triumphant       1408314            41\n                Institute of Management\n                Education (Logo)\n        3.      T.I.M.E. KIDS (LOGO)      2109877            41\n        4.      T.I.M.E                   1725338            16\n\n\n3.           As per the plaint, plaintiff pleads that it came to know for\n\nthe first time in July 2016 of the existence of the defendants on\n\naccount of a newspaper advertisement inserted on 6.7.2016 in the\n\nnewspaper Dainik Bhaskar wherein the defendants were found to have\n\n\n\nCS(COMM) No. 934/2016                                             Page 2 of 4\n adopted an identical trademark TIME and for same coaching services.\n\nIt is pleaded that the defendants have no right to use the trademark\n\nTIME which is identical or nearly identical with the registered\n\ntrademark T.I.M.E of the plaintiff.\n\n\n4.           Defendants have been served in the suit but they have not\n\nappeared and hence they were proceeded ex-parte vide order dated\n\n19.1.2017. Plaintiff has thereafter filed its affidavit by way of\n\nevidence and proved its case.\n\n\n5.           A reference to the affidavit by way of evidence filed on\n\nbehalf of the plaintiff shows that authorization for filing of a suit is in\n\nterms of the Board of Resolution dated 10.7.2017 which has been\n\nproved as Ex.PW1/1. The trademark registrations of the plaintiff have\n\nbeen proved as Ex.PW1/3. Plaintiff has proved its goodwill and\n\nreputation by filing its business turn over ...

# %%
f = open("text_files_html/"+str(int(ik_result.iloc[0,0]))+".html","w+",encoding="utf-8")
f.write(str(ik_result.iloc[0,8]))
f.close()
